# %% [markdown]
# # 라이브러리 불러오기
# 사실 이부분은 문제에서 다 주기 때문에 공부를 따로 할 필요는 없어보여요

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import import seaborn as sns

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense

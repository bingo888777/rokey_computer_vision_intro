# %%
from PIL import Image


# img_idol = Image.open("/content/idol_girl.png")
# img_idol

# %%
# RGBA >> RGB 로 변환 (JPG 투명도 지원 없음)
if img_idol.mode == "RGBA":
  img_idol = img_idol.convert("RGB") # JPG는 A가 없음 PNG는 A가 있음.

# %%
img_idol.save("img_idol.jpg", "JPEG", quality=95)

# %%
Image.open("/content/wafer.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=420x420>

# %%
wafer = Image.open("/content/wafer.jpg")
wafer.save("wafer.png", "PNG")

# %%
# 폴더 전체 jpg >> png

import os
from PIL import Image

input_folder = "images"
output_folder = "output"

os.makedirs(input_folder, exist_ok=True)
os.makedirs(output_folder, exist_ok=True)

for file in os.listdir(input_folder):
    if file.endswith('.jpg'):
        img = Image.open(os.path.join(input_folder, file))

        new_name = file.replace('.jpg', '.png')
        img.save(os.path.join(output_folder, new_name), "PNG")

# %%
# 폴더 전체 jpg >> png 다시 써보기

import os
from PIL import image

input_folder = 'images'
output_folder = 'output'

os.makedirs(input_folder, dexist_ok=True)
os.makedirs(output_folder, dexist_ok=True)

for file in os.listdir(input_folder):
    if file.endswith('.jpg'):
        img = image.open(os.path.join(input_folder, file))

        new_name = file.replace('.jpg', ',png')
        img.save(os.path.join(output_folder, new_name), "PNG")

# %%
# eos

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

path = '/content/rabbit.jpg'

img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img,(400,320)) # 여기서는 x, y로 넣음
plt.imshow(img)
plt.show()

# %%
# 기본 정보 파악 (가로, 세로) # 여기선 y,x로 나옴.
img.shape
# Out:
# (320, 400, 3)

# %%
height, width = img.shape[:2]
# Out:
# 320

# %%
# x = [100:350]
# y = [50:250]
